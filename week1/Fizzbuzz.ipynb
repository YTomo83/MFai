# %%
nl = []
for i in range(1,21):
  if i % 3 == 0 and i % 5 == 0:
    nl.append("FizzBuzz")
  elif i % 3 == 0:
    nl.append("Fizz")
  elif i % 5 == 0:
    nl.append("Buzz")
  else:
    nl.append(i)

print(nl)
# Out:
# [1, 2, 'Fizz', 4, 'Buzz', 'Fizz', 7, 8, 'Fizz', 'Buzz', 11, 'Fizz', 13, 14, 'FizzBuzz', 16, 17, 'Fizz', 19, 'Buzz']
